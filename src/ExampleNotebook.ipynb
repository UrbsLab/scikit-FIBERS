# %% [markdown]
# # scikit-FIBERS Example Code

# %% [markdown]
# ## Installation and Imports
# How to setup and use scikit-FIBERS

# %%
# !pip uninstall scikit-fibers --yes

# %%
import pandas as pd
from skfibers import FIBERS
from sklearn.metrics import classification_report
from skfibers.experiments.datagen import create_data_simulation_bin
from skfibers.experiments.datagen_evolvable_threshold import create_data_simulation_bin_evolve
print("done")
# Out:
# done

# %% [markdown]
# ## Creating Simulation Data by provided functionality

# %%
# data = create_data_simulation_bin(number_of_instances=10000, number_of_features=50, number_of_features_in_bin=10,
               #                   no_fail_proportion=0.5, mm_frequency_range=(0.4, 0.5), noise_frequency=0.1,
                #                  class0_time_to_event_range=(1.5, 0.2), class1_time_to_event_range=(1, 0.2),
                 #                 censoring_frequency=0.5, random_seed=42, negative=False)

raw_data = pd.read_csv('$Imp1.csv')
print(raw_data.columns)
raw_data.head(10)
raw_data.select_dtypes(['object']).columns

# Setting and loading data with features
amino_acids = ['A1', 'A10', 'A100', 'A101', 'A102', 'A103', 'A104', 'A105', 'A106', 'A107', 'A108', 'A109', 'A11', 'A110', 'A111', 'A112', 'A113', 'A114', 'A115', 'A116', 'A117', 'A118', 'A119', 'A12', 'A120', 'A121', 'A122', 'A123', 'A124', 'A125', 'A126', 'A127', 'A128', 'A129', 'A13', 'A130', 'A131', 'A132', 'A133', 'A134', 'A135', 'A136', 'A137', 'A138', 'A139', 'A14', 'A140', 'A141', 'A142', 'A143', 'A144', 'A145', 'A146', 'A147', 'A148', 'A149', 'A15', 'A150', 'A151', 'A152', 'A153', 'A154', 'A155', 'A156', 'A157', 'A158', 'A159', 'A16', 'A160', 'A161', 'A162', 'A163', 'A164', 'A165', 'A166', 'A167', 'A168', 'A169', 'A17', 'A170', 'A171', 'A172', 'A173', 'A174', 'A175', 'A176', 'A177', 'A178', 'A179', 'A18', 'A180', 'A181', 'A182', 'A183', 'A184', 'A185', 'A186', 'A187', 'A188', 'A189', 'A19', 'A190', 'A191', 'A192', 'A193', 'A194', 'A195', 'A196', 'A197', 'A198', 'A199', 'A2', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'A3', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'A4', 'A40', 'A41', 'A42', 'A43', 'A44', 'A45', 'A46', 'A47', 'A48', 'A49', 'A5', 'A50', 'A51', 'A52', 'A53', 'A54', 'A55', 'A56', 'A57', 'A58', 'A59', 'A6', 'A60', 'A61', 'A62', 'A63', 'A64', 'A65', 'A66', 'A67', 'A68', 'A69', 'A7', 'A70', 'A71', 'A72', 'A73', 'A74', 'A75', 'A76', 'A77', 'A78', 'A79', 'A8', 'A80', 'A81', 'A82', 'A83', 'A84', 'A85', 'A86', 'A87', 'A88', 'A89', 'A9', 'A90', 'A91', 'A92', 'A93', 'A94', 'A95', 'A96', 'A97', 'A98', 'A99', 'B1', 'B10', 'B100', 'B101', 'B102', 'B103', 'B104', 'B105', 'B
              'dcadcodcva', 'dcadcodcnst', 'dcadcodoth', 'don_cmv_negative', 
              'don_htn_0c', 'ln_don_wgt_kg_0c', 'ln_don_wgt_kg_0c_s55', 
              'don_ecd', 'age_ecd', 'yearslice', 'REC_AGE_AT_TX', 
              'rec_age_spline_35', 'rec_age_spline_50', 'rec_age_spline_65', 
              'diab_noted', 'age_diab', 'dm_can_age_spline_50', 
              'can_dgn_htn_ndm', 'can_dgn_pk_ndm', 'can_dgn_gd_ndm', 
              'rec_prev_ki_tx', 'rec_prev_ki_tx_dm', 'rbmi_0c', 'rbmi_miss', 
              'rbmi_gt_20', 'rbmi_DM', 'rbmi_gt_20_DM', 'ln_c_hd_m', 
              'ln_c_hd_0c', 'ln_c_hd_m_ptx', 'PKPRA_MS', 'PKPRA_1080', 
              'PKPRA_GE80', 'hispanic', 'CAN_RACE_BLACK', 'CAN_RACE_asian', 
              'CAN_RACE_WHITE', 'mm0', 'mmDR0', 'mmDR1', 'mmA0', 'mmA1', 
              'mmB0', 'mmB1', 'mmC0', 'mmC1', 'mmDQ0', 'mmDQ1']
features = covariates + amino_acids + ["grf_fail", "graftyrs"]
data = raw_data[features]

# Droping Rows with NaN values
nan_values = data[pd.isnull(data).any(axis=1)]
data_without_nan = data.dropna()

# Label Encoding Values
cat_columns = data_without_nan.select_dtypes(['object']).columns
data_without_nan[cat_columns] = data_without_nan[cat_columns].apply(lambda x: pd.factorize(x)[0])

grf_fail = data_without_nan[['grf_fail']]
# data_without_nan = data_without_nan.drop('grf_fail', axis=1)
# Out:
# /var/folders/d2/dszhc89x77s1wml7ylg59hm80000gn/T/ipykernel_14221/1249377368.py:6: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_data = pd.read_csv('$Imp1.csv')
# Index(['PX_ID', 'ORG_TY', 'DON_TY', 'DON_AGE', 'CAN_GENDER', 'CAN_RACE',
#        'CAN_ABO', 'REC_TX_ORG_TY', 'REC_AGE_AT_TX', 'CAN_SOURCE',
#        ...
#        'DRB192', 'DRB193', 'DRB194', '_imputation_', 'mmC0', 'mmC1', 'mmDQ0',
#        'mmDQ1', 'FIRST_TX', 'MOST_RECENT_TX'],
#       dtype='object', length=865)

# %%
data_without_nan.head(10)
list(data_without_nan.select_dtypes(['object']).columns)
# Out:
# []

# %% [markdown]
# ## Fitting FIBERS on the Data

# %%
#fibers = FIBERS(label_name="Censoring", duration_name="Duration", 
fibers = FIBERS(label_name="grf_fail", duration_name="graftyrs", 
                given_starting_point=False, amino_acid_start_point=None,
                amino_acid_bins_start_point=None, iterations=100,
                set_number_of_bins=50, min_features_per_group=2,
                max_number_of_groups_with_feature=2,
                informative_cutoff=0.2, crossover_probability=0.8,
                mutation_probability=0.4, elitism_parameter=0.8,
                random_seed=42, set_threshold = 0, evolving_probability = 0.0,
                min_threshold = 0, max_threshold = 3,
                merge_probability = 0.2, covariates = covariates, scoring_method = "AIC",threshold = "no")
fibers = fibers.fit(data_without_nan)
# Out:
#  27%|█████████▉                           | 27/100 [1:00:26<2:43:23, 134.30s/it]

# %% [markdown]
# ## Accessing results and internal functions

# %%
def hazard_ratio(data_without_nan, bin_scores, bins, covariates, index=0):
    sorted_bin_scores = dict(sorted(bin_scores.items(), key=lambda item: item[1], reverse=True))
    sorted_bin_list = list(sorted_bin_scores.keys())
    sorted_bin_feature_importance_values = list(sorted_bin_scores.values())
    Bin = bins[sorted_bin_list[index]]
    d_data = data_without_nan.copy()
    d_data['Bin'] = d_data[Bin].sum(axis=1)
    column_values = d_data['Bin'].to_list()
    for r in range(0, len(column_values)):
        if column_values[r] > 0:
            column_values[r] = 1
    d_data['Bin'] = column_values
    coxmodeldata =  d_data[covariates + ["grf_fail", "graftyrs", "Bin"]]
    cat_columns = coxmodeldata.select_dtypes(['object']).columns
    coxmodeldata[cat_columns] = coxmodeldata[cat_columns].apply(lambda x: pd.factorize(x)[0])
    cph = CoxPHFitter()
    cph.fit(coxmodeldata,"graftyrs",event_col="grf_fail", show_progress=True)
    cph_summary_file = "docs/cph_summary.html"
    cph.summary.to_html(cph_summary_file, index = True)
    return cph.summary

# %%
from lifelines import CoxPHFitter

# %%
summary = hazard_ratio(data_without_nan, fibers.bin_scores, fibers.bins, covariates, index=0)
summary
# Out:
# Iteration 1: norm_delta = 0.68692, step_size = 0.9500, log_lik = -674771.34752, newton_decrement = 6446.38496, seconds_since_start = 1.1
# Iteration 2: norm_delta = 0.19310, step_size = 0.9500, log_lik = -668566.15467, newton_decrement = 148.89114, seconds_since_start = 2.1
# Iteration 3: norm_delta = 0.02000, step_size = 0.9500, log_lik = -668414.32989, newton_decrement = 1.29416, seconds_since_start = 3.2
# Iteration 4: norm_delta = 0.00013, step_size = 1.0000, log_lik = -668413.03010, newton_decrement = 0.00007, seconds_since_start = 4.2
# Iteration 5: norm_delta = 0.00000, step_size = 1.0000, log_lik = -668413.03003, newton_decrement = 0.00000, seconds_since_start = 5.3
# Convergence success after 5 iterations.
#                           coef  exp(coef)  se(coef)  coef lower 95%  \
# covariate
# shared                0.110235   1.116541  0.010202        0.090240
# DCD                   0.078212   1.081352  0.014360        0.050067
# DON_AGE              -0.010623   0.989433  0.004818       -0.020066
# donage_slope_ge18     0.020269   1.020476  0.004956        0.010554
# dcadcodanox           0.043058   1.043998  0.012457        0.018642
# dcadcodcva            0.068499   1.070900  0.010873        0.047189
# dcadcodcnst          -0.000475   0.999525  0.051353       -0.101125
# dcadcodoth            0.059806   1.061631  0.027604        0.005703
# don_cmv_negative     -0.012318   0.987758  0.008646       -0.029264
# don_htn_0c            0.139608   1.149823  0.010541        0.118947
# ln_don_wgt_kg_0c     -0.292836   0.746144  0.078586       -0.446862
# ln_don_wgt_kg_0c_s55  0.268138   1.307528  0.084526        0.102471
# don_ecd               0.251807   1.286348  0.053603        0.146747
# age_ecd              -0.003585   0.996421  0.000890       -0.005331
# yearslice            -0.053435   0.947968  0.001228       -0.055841
# REC_AGE_AT_TX         0.055209   1.056762  0.005741        0.043957
# rec_age_spline_35    -0.005487   0.994528  0.001331       -0.008096
# rec_age_spline_50     0.029113   1.029541  0.002440        0.024330
# rec_age_spline_65     0.012149   1.012224  0.002596        0.007061
# diab_noted           -0.031228   0.969254  0.097901       -0.223111
# age_diab              0.009536   1.009582  0.002069        0.005481
# dm_can_age_spline_50 -0.015458   0.984660  0.002911       -0.021164
# can_dgn_htn_ndm       0.093782   1.098320  0.013133        0.068041
# can_dgn_pk_ndm       -0.277156   0.757936  0.019347       -0.315076
# can_dgn_gd_ndm       -0.008682   0.991356  0.014723       -0.037539
# rec_prev_ki_tx        0.148975   1.160644  0.016081        0.117456
# rec_prev_ki_tx_dm    -0.061334   0.940509  0.029230       -0.118624
# rbmi_0c              -0.031380   0.969107  0.007346       -0.045777
# rbmi_miss            -0.504174   0.604004  0.144726       -0.787831
# rbmi_gt_20            0.044977   1.046003  0.007681        0.029922
# rbmi_DM               0.000931   1.000931  0.001668       -0.002338
# rbmi_gt_20_DM        -0.006996   0.993029  0.002886       -0.012652
# ln_c_hd_m            -0.068580   0.933719  0.020115       -0.108004
# ln_c_hd_0c            0.163508   1.177635  0.008143        0.147548
# ln_c_hd_m_ptx         0.087219   1.091136  0.041133        0.006600
# PKPRA_MS             -0.008899   0.991140  0.022696       -0.053383
# PKPRA_1080            0.048263   1.049447  0.010164        0.028341
# PKPRA_GE80            0.187310   1.206001  0.014117        0.159642
# hispanic             -0.157313   0.854437  0.037628       -0.231062
# CAN_RACE_BLACK        0.213365   1.237836  0.036385        0.142052
# CAN_RACE_asian       -0.272363   0.761578  0.040487       -0.351716
# CAN_RACE_WHITE        0.130434   1.139323  0.036302        0.059283
# mm0                   0.032865   1.033411  0.027127       -0.020304
# mmDR0                -0.107925   0.897695  0.015460       -0.138226
# mmDR1                -0.051462   0.949840  0.009586       -0.070251
# mmA0                 -0.060365   0.941420  0.016564       -0.092831
# mmA1                 -0.000665   0.999336  0.009154       -0.018606
# mmB0                 -0.101153   0.903795  0.020761       -0.141843
# mmB1                 -0.022043   0.978198  0.009893       -0.041433
# mmC0                 -0.006610   0.993412  0.028516       -0.062501
# mmC1                  0.036298   1.036965  0.011378        0.013998
# mmDQ0                -0.014494   0.985611  0.013452       -0.040860
# mmDQ1                -0.020394   0.979812  0.009205       -0.038437
# Bin                   0.064240   1.066349  0.012694        0.039361
#
#                       coef upper 95%  exp(coef) lower 95%  \
# covariate
# shared                      0.130231             1.094437
# DCD                         0.106357             1.051342
# DON_AGE                    -0.001180             0.980134
# donage_slope_ge18           0.029983             1.010610
# dcadcodanox                 0.067473             1.018817
# dcadcodcva                  0.089810             1.048320
# dcadcodcnst                 0.100175             0.903820
# dcadcodoth                  0.113910             1.005719
# don_cmv_negative            0.004629             0.971160
# don_htn_0c                  0.160268             1.126311
# ln_don_wgt_kg_0c           -0.138811             0.639632
# ln_don_wgt_kg_0c_s55        0.433806             1.107905
# don_ecd                     0.356867             1.158061
# age_ecd                    -0.001840             0.994683
# yearslice                  -0.051029             0.945690
# REC_AGE_AT_TX               0.066461             1.044938
# rec_age_spline_35          -0.002879             0.991937
# rec_age_spline_50           0.033895             1.024629
# rec_age_spline_65           0.017238             1.007086
# diab_noted                  0.160655             0.800026
# age_diab                    0.013591             1.005496
# dm_can_age_spline_50       -0.009753             0.979059
# can_dgn_htn_ndm             0.119523             1.070409
# can_dgn_pk_ndm             -0.239237             0.729734
# can_dgn_gd_ndm              0.020176             0.963157
# rec_prev_ki_tx              0.180494             1.124632
# rec_prev_ki_tx_dm          -0.004043             0.888142
# rbmi_0c                    -0.016983             0.955255
# rbmi_miss                  -0.220517             0.454830
# rbmi_gt_20                  0.060032             1.030374
# rbmi_DM                     0.004200             0.997665
# rbmi_gt_20_DM              -0.001340             0.987428
# ln_c_hd_m                  -0.029156             0.897624
# ln_c_hd_0c                  0.179469             1.158989
# ln_c_hd_m_ptx               0.167838             1.006622
# PKPRA_MS                    0.035585             0.948017
# PKPRA_1080                  0.068185             1.028747
# PKPRA_GE80                  0.214978             1.173091
# hispanic                   -0.083564             0.793691
# CAN_RACE_BLACK              0.284678             1.152636
# CAN_RACE_asian             -0.193010             0.703480
# CAN_RACE_WHITE              0.201586             1.061075
# mm0                         0.086034             0.979901
# mmDR0                      -0.077625             0.870902
# mmDR1                      -0.032673             0.932160
# mmA0                       -0.027900             0.911347
# mmA1                        0.017277             0.981566
# mmB0                       -0.060463             0.867757
# mmB1                       -0.002653             0.959414
# mmC0                        0.049280             0.939412
# mmC1                        0.058598             1.014097
# mmDQ0                       0.011872             0.959963
# mmDQ1                      -0.002352             0.962293
# Bin                         0.089119             1.040146
#
#                       exp(coef) upper 95%  cmp to          z             p  \
# covariate
# shared                           1.139091     0.0  10.805446  3.243778e-27
# DCD                              1.112219     0.0   5.446546  5.135744e-08
# DON_AGE                          0.998821     0.0  -2.204871  2.746312e-02
# donage_slope_ge18                1.030437     0.0   4.089417  4.324587e-05
# dcadcodanox                      1.069802     0.0   3.456435  5.473712e-04
# dcadcodcva                       1.093966     0.0   6.300002  2.976421e-10
# dcadcodcnst                      1.105364     0.0  -0.009250  9.926198e-01
# dcadcodoth                       1.120651     0.0   2.166559  3.026851e-02
# don_cmv_negative                 1.004640     0.0  -1.424580  1.542785e-01
# don_htn_0c                       1.173826     0.0  13.244011  4.886753e-40
# ln_don_wgt_kg_0c                 0.870392     0.0  -3.726327  1.942901e-04
# ln_don_wgt_kg_0c_s55             1.543119     0.0   3.172267  1.512537e-03
# don_ecd                          1.428846     0.0   4.697640  2.631853e-06
# age_ecd                          0.998162     0.0  -4.026427  5.663075e-05
# yearslice                        0.950251     0.0 -43.530047  0.000000e+00
# REC_AGE_AT_TX                    1.068719     0.0   9.616905  6.784147e-22
# rec_age_spline_35                0.997125     0.0  -4.122898  3.741347e-05
# rec_age_spline_50                1.034476     0.0  11.931288  8.130522e-33
# rec_age_spline_65                1.017388     0.0   4.679335  2.878074e-06
# diab_noted                       1.174280     0.0  -0.318976  7.497447e-01
# age_diab                         1.013684     0.0   4.609286  4.040533e-06
# dm_can_age_spline_50             0.990294     0.0  -5.310705  1.092020e-07
# can_dgn_htn_ndm                  1.126959     0.0   7.140718  9.284438e-13
# can_dgn_pk_ndm                   0.787228     0.0 -14.325584  1.514497e-46
# can_dgn_gd_ndm                   1.020381     0.0  -0.589642  5.554309e-01
# rec_prev_ki_tx                   1.197809     0.0   9.263762  1.973531e-20
# rec_prev_ki_tx_dm                0.995965     0.0  -2.098296  3.587904e-02
# rbmi_0c                          0.983160     0.0  -4.272004  1.937237e-05
# rbmi_miss                        0.802104     0.0  -3.483655  4.946172e-04
# rbmi_gt_20                       1.061870     0.0   5.855327  4.760724e-09
# rbmi_DM                          1.004208     0.0   0.558226  5.766899e-01
# rbmi_gt_20_DM                    0.998661     0.0  -2.424124  1.534538e-02
# ln_c_hd_m                        0.971265     0.0  -3.409428  6.509920e-04
# ln_c_hd_0c                       1.196582     0.0  20.078950  1.127526e-89
# ln_c_hd_m_ptx                    1.182745     0.0   2.120420  3.397063e-02
# PKPRA_MS                         1.036225     0.0  -0.392096  6.949872e-01
# PKPRA_1080                       1.070563     0.0   4.748291  2.051430e-06
# PKPRA_GE80                       1.239835     0.0  13.268681  3.517186e-40
# hispanic                         0.919832     0.0  -4.180769  2.905253e-05
# CAN_RACE_BLACK                   1.329333     0.0   5.864105  4.515609e-09
# CAN_RACE_asian                   0.824474     0.0  -6.727195  1.729645e-11
# CAN_RACE_WHITE                   1.223341     0.0   3.592988  3.269078e-04
# mm0                              1.089843     0.0   1.211505  2.257018e-01
# mmDR0                            0.925312     0.0  -6.981055  2.929715e-12
# mmDR1                            0.967855     0.0  -5.368289  7.948729e-08
# mmA0                             0.972486     0.0  -3.644296  2.681247e-04
# mmA1                             1.017427     0.0  -0.072600  9.421245e-01
# mmB0                             0.941329     0.0  -4.872327  1.102916e-06
# mmB1                             0.997350     0.0  -2.228156  2.587008e-02
# mmC0                             1.050515     0.0  -0.231802  8.166916e-01
# mmC1                             1.060349     0.0   3.190274  1.421377e-03
# mmDQ0                            1.011943     0.0  -1.077433  2.812871e-01
# mmDQ1                            0.997651     0.0  -2.215436  2.673012e-02
# Bin                              1.093211     0.0   5.060862  4.173650e-07
#
#                         -log2(p)
# covariate
# shared                 87.994383
# DCD                    24.214852
# DON_AGE                 5.186361
# donage_slope_ge18      14.497078
# dcadcodanox            10.835193
# dcadcodcva             31.645702
# dcadcodcnst             0.010687
# dcadcodoth              5.046039
# don_cmv_negative        2.696391
# don_htn_0c            130.588248
# ln_don_wgt_kg_0c       12.329500
# ln_don_wgt_kg_0c_s55    9.368814
# don_ecd                18.535490
# age_ecd                14.108055
# yearslice                    inf
# REC_AGE_AT_TX          70.320251
# rec_age_spline_35      14.706083
# rec_age_spline_50     106.600279
# rec_age_spline_65      18.406465
# diab_noted              0.415529
# age_diab               17.917023
# dm_can_age_spline_50   23.126497
# can_dgn_htn_ndm        39.970251
# can_dgn_pk_ndm        152.209853
# can_dgn_gd_ndm          0.848321
# rec_prev_ki_tx         65.457783
# rec_prev_ki_tx_dm       4.800715
# rbmi_0c                15.655640
# rbmi_miss              10.981400
# rbmi_gt_20             27.646172
# rbmi_DM                 0.794132
# rbmi_gt_20_DM           6.026052
# ln_c_hd_m              10.585072
# ln_c_hd_0c            295.478440
# ln_c_hd_m_ptx           4.879568
# PKPRA_MS                0.524942
# PKPRA_1080             18.894939
# PKPRA_GE80            131.062702
# hispanic               15.070977
# CAN_RACE_BLACK         27.722432
# CAN_RACE_asian         35.750733
# CAN_RACE_WHITE         11.578829
# mm0                     2.147510
# mmDR0                  38.312377
# mmDR1                  23.584701
# mmA0                   11.864808
# mmA1                    0.086010
# mmB0                   19.790246
# mmB1                    5.272571
# mmC0                    0.292137
# mmC1                    9.458495
# mmDQ0                   1.829885
# mmDQ1                   5.225390
# Bin                    21.192187

# %% [markdown]
# ### All Bins and coressponding Log-Rank Scores

# %%
# Assuming fibers.get_bin_scores() returns a DataFrame
bin_scores = fibers.get_bin_scores()

# Get the first 10 rows
first_10_rows = bin_scores.head(10)

# Save the first 10 rows to a CSV file in the "docs" folder
bin_scores_file = "docs/bin_scores_first_10.html"
first_10_rows.to_html(bin_scores_file, index=True)

# %% [markdown]
# ### Viewing Transformed Rules/Bins/Features

# %%
# Assuming fibers.transform(data_without_nan) returns a DataFrame
data_tranformed = fibers.transform(data_without_nan)

# Save data_tranformed to a CSV file in the "docs" folder
data_tranformed_file = "docs/data_tranformed.html"
data_tranformed.to_html(data_tranformed_file, index=False)

# %% [markdown]
# ### Checking Top Rule Train Accuracy

# %%
print("Accuracy: ", fibers.score(data_without_nan, grf_fail))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print("Accuracy: ", fibers.score(data_without_nan, grf_fail))
#
# File ~/Desktop/scikit-FIBERS-evolving/src/skfibers/new_fibers.py:358, in FIBERS.score(self, x, y)
#     356 if not self.hasTrained:
#     357     raise Exception("Model must be fit first")
# --> 358 y_pred = self.predict(x)
#     359 return accuracy_score(y, y_pred)
#
# File ~/Desktop/scikit-FIBERS-evolving/src/skfibers/new_fibers.py:343, in FIBERS.predict(self, x)
#     341 if not self.hasTrained:
#     342     raise Exception("Model must be trained first")
# --> 343 _, _, _, _, top_bin = self.get_duration_event(bin_order=0)
#     344 top_or_rule = self.bins[top_bin]
#     345 # check each column if
#
# File ~/Desktop/scikit-FIBERS-evolving/src/skfibers/new_fibers.py:392, in FIBERS.get_duration_event(self, bin_order)
#     388 sorted_bin_list = list(sorted_bin_list.keys())
#     390 top_bin = sorted_bin_list[bin_order]
# --> 392 df_0 = self.bin_feature_matrix.loc[self.bin_feature_matrix[top_bin] <= threshold] #SPHIA
#     393 df_1 = self.bin_feature_matrix.loc[self.bin_feature_matrix[top_bin] > threshold]
#     395 durations_no = df_0[self.duration_name].to_list()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/arraylike.py:54, in OpsMixin.__le__(self, other)
#      52 @unpack_zerodim_and_defer("__le__")
#      53 def __le__(self, other):
# ---> 54     return self._cmp_method(other, operator.le)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/series.py:6243, in Series._cmp_method(self, other, op)
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6242 with np.errstate(all="ignore"):
# -> 6243     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6245 return self._construct_result(res_values, name=res_name)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:284, in comparison_op(left, right, op)
#     280         res_values = np.zeros(lvalues.shape, dtype=bool)
#     282 elif is_numeric_v_string_like(lvalues, rvalues):
#     283     # GH#36377 going through the numexpr path would incorrectly raise
# --> 284     return invalid_comparison(lvalues, rvalues, op)
#     286 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
#     287     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/ops/invalid.py:36, in invalid_comparison(left, right, op)
#      34 else:
#      35     typ = type(right).__name__
# ---> 36     raise TypeError(f"Invalid comparison between dtype={left.dtype} and {typ}")
#      37 return res_values
#
# TypeError: Invalid comparison between dtype=int64 and str

# %%
y = fibers.predict(data_without_nan)

# %%
print(classification_report(y, grf_fail))
