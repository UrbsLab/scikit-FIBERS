# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# plt.rcParams['font.size'] = 16
import seaborn as sns
sns.set_theme()
# plt.rcParams['font.family'] = 'Times New Roman'

# %%
root_folder = "run_history/"
summary_files = list()
score_files = list()
exp_files = os.listdir(root_folder)
for exp_file in exp_files:
    if exp_file.endswith(".csv"):
        if 'summary' in exp_file:
            summary_files.append(exp_file)
        if 'scores' in exp_file and 'old' not in exp_file:
            score_files.append(exp_file)
summary_files = sorted(summary_files)
score_files = sorted(score_files)

# %%
plot_df = pd.DataFrame()
metric = "Accuracy"
top = 10
for sfile in score_files:
    if 'False' in sfile and '0.0' in sfile:
        tdf = pd.read_csv(root_folder + '/' + sfile)
        if 'thresh_0' in sfile:
            plot_df['Thresh 0'] = tdf[metric]
        if 'thresh_1' in sfile:
            plot_df['Thresh 1'] = tdf[metric]
        if 'thresh_2' in sfile:
            plot_df['Thresh 2'] = tdf[metric]
        if 'thresh_3' in sfile:
            plot_df['Thresh 3'] = tdf[metric]
false_0 = plot_df.head(top)
plot_df = pd.DataFrame()
for sfile in score_files:
    if 'True' in sfile and '0.0' in sfile:
        tdf = pd.read_csv(root_folder + '/' + sfile)
        if 'thresh_0' in sfile:
            plot_df['Thresh 0'] = tdf[metric]
        if 'thresh_1' in sfile:
            plot_df['Thresh 1'] = tdf[metric]
        if 'thresh_2' in sfile:
            plot_df['Thresh 2'] = tdf[metric]
        if 'thresh_3' in sfile:
            plot_df['Thresh 3'] = tdf[metric]
true_0 = plot_df.head(top)
plot_df = pd.DataFrame()
for sfile in score_files:
    if 'True' in sfile and '0.5' in sfile:
        tdf = pd.read_csv(root_folder + '/' + sfile)
        if 'thresh_0' in sfile:
            plot_df['Thresh 0'] = tdf[metric]
        if 'thresh_1' in sfile:
            plot_df['Thresh 1'] = tdf[metric]
        if 'thresh_2' in sfile:
            plot_df['Thresh 2'] = tdf[metric]
        if 'thresh_3' in sfile:
            plot_df['Thresh 3'] = tdf[metric]
true_1 = plot_df.head(top)
plot_df = pd.DataFrame()
for sfile in score_files:
    if 'True' in sfile and '1.0' in sfile:
        tdf = pd.read_csv(root_folder + '/' + sfile)
        if 'thresh_0' in sfile:
            plot_df['Thresh 0'] = tdf[metric]
        if 'thresh_1' in sfile:
            plot_df['Thresh 1'] = tdf[metric]
        if 'thresh_2' in sfile:
            plot_df['Thresh 2'] = tdf[metric]
        if 'thresh_3' in sfile:
            plot_df['Thresh 3'] = tdf[metric]
true_2 = plot_df.head(top)

# %%
def box_plot(data, edge_color, fill_color, pos_sep=0):
    positions = list(np.array(list(range(1,data.shape[1]+1))) + pos_sep)
    bp = ax.boxplot(data, patch_artist=True, widths=0.1, positions=positions)
    
    for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(bp[element], color=edge_color)

    for patch in bp['boxes']:
        patch.set(facecolor=fill_color, fill=True)       
        
    return bp

# %%
fig, ax = plt.subplots()
seps = np.linspace(-0.25,0.25, 4)
bp1 = box_plot(false_0, plt.cm.gray(1), plt.cm.gray(1), seps[0])
bp2 = box_plot(true_0, plt.cm.gray(0.7), plt.cm.gray(0.7), seps[1])
bp3 = box_plot(true_1, plt.cm.gray(0.5), plt.cm.gray(0.5), seps[2])
bp4 = box_plot(true_2, plt.cm.gray(0.3), plt.cm.gray(0.3), seps[3])

ax.legend([bp1["boxes"][0], bp2["boxes"][0], bp3["boxes"][0], bp4["boxes"][0]], 
          ['No Adaptive Thresholding (Original Method)', 'Adaptive with 0 evolving prob. (Best Score)', 
           'Adaptive with 0.5 evolving prob.', 'Adaptive with 1 evolving prob.'], prop={'size': 10})
ax.set_ylim(-0.1, 1.1)
plt.xticks([1,2,3,4], [0,1,2,3])
plt.ylabel('True Risk Accuracy')
plt.xlabel('Ground Truth Threshold')
# plt.title('Accuracy of top 10 FIBERS bins with Different Risk Thresholds')
plt.savefig('fig1_1.png', dpi=600)

# %%
plot_df = pd.DataFrame()
metric = "Score"
top = 10
for sfile in score_files:
    if 'False' in sfile and '0.0' in sfile:
        tdf = pd.read_csv(root_folder + '/' + sfile)
        if 'thresh_0' in sfile:
            plot_df['Thresh 0'] = tdf[metric]
        if 'thresh_1' in sfile:
            plot_df['Thresh 1'] = tdf[metric]
        if 'thresh_2' in sfile:
            plot_df['Thresh 2'] = tdf[metric]
        if 'thresh_3' in sfile:
            plot_df['Thresh 3'] = tdf[metric]
false_0 = plot_df.head(top)
plot_df = pd.DataFrame()
for sfile in score_files:
    if 'True' in sfile and '0.0' in sfile:
        tdf = pd.read_csv(root_folder + '/' + sfile)
        if 'thresh_0' in sfile:
            plot_df['Thresh 0'] = tdf[metric]
        if 'thresh_1' in sfile:
            plot_df['Thresh 1'] = tdf[metric]
        if 'thresh_2' in sfile:
            plot_df['Thresh 2'] = tdf[metric]
        if 'thresh_3' in sfile:
            plot_df['Thresh 3'] = tdf[metric]
true_0 = plot_df.head(top)
plot_df = pd.DataFrame()
for sfile in score_files:
    if 'True' in sfile and '0.5' in sfile:
        tdf = pd.read_csv(root_folder + '/' + sfile)
        if 'thresh_0' in sfile:
            plot_df['Thresh 0'] = tdf[metric]
        if 'thresh_1' in sfile:
            plot_df['Thresh 1'] = tdf[metric]
        if 'thresh_2' in sfile:
            plot_df['Thresh 2'] = tdf[metric]
        if 'thresh_3' in sfile:
            plot_df['Thresh 3'] = tdf[metric]
true_1 = plot_df.head(top)
plot_df = pd.DataFrame()
for sfile in score_files:
    if 'True' in sfile and '1.0' in sfile:
        tdf = pd.read_csv(root_folder + '/' + sfile)
        if 'thresh_0' in sfile:
            plot_df['Thresh 0'] = tdf[metric]
        if 'thresh_1' in sfile:
            plot_df['Thresh 1'] = tdf[metric]
        if 'thresh_2' in sfile:
            plot_df['Thresh 2'] = tdf[metric]
        if 'thresh_3' in sfile:
            plot_df['Thresh 3'] = tdf[metric]
true_2 = plot_df.head(top)

# %%
fig, ax = plt.subplots()
seps = np.linspace(-0.25,0.25, 4)
bp1 = box_plot(false_0, plt.cm.gray(1), plt.cm.gray(1), seps[0])
bp2 = box_plot(true_0, plt.cm.gray(0.7), plt.cm.gray(0.7), seps[1])
bp3 = box_plot(true_1, plt.cm.gray(0.5), plt.cm.gray(0.5), seps[2])
bp4 = box_plot(true_2, plt.cm.gray(0.3), plt.cm.gray(0.3), seps[3])

ax.legend([bp1["boxes"][0], bp2["boxes"][0], bp3["boxes"][0], bp4["boxes"][0]], 
          ['No Adaptive Thresholding (Original Method)', 'Adaptive with 0 evolving prob. (Best Score)', 
           'Adaptive with 0.5 evolving prob.', 'Adaptive with 1 evolving prob.'], prop={'size': 10})
ax.set_ylim(0, 8000)
plt.xticks([1,2,3,4], [0,1,2,3])
plt.ylabel('Log Rank Scores')
plt.xlabel('Ground Truth Threshold')
# plt.title('Log Rank Scores of top 10 FIBERS bins with Different Risk Thresholds')
plt.show()

# %%
pd.read_csv(root_folder + '/' + summary_files[2])
# Out:
#                                        Unnamed: 0                       0
# 0                                           Bin #                   Bin 1
# 1                            Top Bin of Features:   ['P_1', 'P_4', 'P_5']
# 2                                  Log-Rank Score      1231.6179929956288
# 3  Number of Instances with No Mismatches in Bin:                    4410
# 4   Number of Instances with Mismatch(es) in Bin:                    5590
# 5                     p-value from Log Rank Test:  8.201646663403752e-270
# 6                                       Threshold                       0

# %%
root_folder = "run_history_1/"
nf_summary_files_1 = list()
nf_score_files_1 = list()
exp_files = os.listdir(root_folder)
for exp_file in exp_files:
    if exp_file.endswith(".csv"):
        if 'summary' in exp_file:
            nf_summary_files_1.append(exp_file)
        if 'scores' in exp_file and 'old' not in exp_file:
            nf_score_files_1.append(exp_file)
nf_summary_files_1 = sorted(nf_summary_files_1)
nf_score_files_1 = sorted(nf_score_files_1)
plot_df = pd.DataFrame()
metric = "Accuracy"
top = 20
for sfile in nf_score_files_1:
    for i in range(200, 900, 100):
        if str(i) in sfile:
            try:
                tdf = pd.read_csv(root_folder + '/' + sfile)
                plot_df[i] = tdf[metric]
            except Exception as e:
                print(e)
nf_1 = plot_df.head(top)

# %%
root_folder = "run_history_2/"
nf_summary_files_2 = list()
nf_score_files_2 = list()
exp_files = os.listdir(root_folder)
for exp_file in exp_files:
    if exp_file.endswith(".csv"):
        if 'summary' in exp_file:
            nf_summary_files_2.append(exp_file)
        if 'scores' in exp_file and 'old' not in exp_file:
            nf_score_files_2.append(exp_file)
nf_summary_files_2 = sorted(nf_summary_files_2)
nf_score_files_2 = sorted(nf_score_files_2)
plot_df = pd.DataFrame()
metric = "Accuracy"
top = 20
for sfile in nf_score_files_2:
    for i in range(200, 900, 100):  
        if str(i) in sfile and '0.0' in sfile:
            try:
                tdf = pd.read_csv(root_folder + '/' + sfile)
                plot_df[i] = tdf[metric]
            except:
                continue
nf_2 = plot_df.head(top)

# %%
fig, ax = plt.subplots()
seps = np.linspace(-0.1,0.1, 2)
bp1 = box_plot(nf_1, plt.cm.gray(1), plt.cm.gray(1), seps[0])
bp2 = box_plot(nf_2, plt.cm.gray(0.5), plt.cm.gray(0.5), seps[1])
ax.legend([bp1["boxes"][0], bp2["boxes"][0]], 
          ['No Adaptive Thresholding (Original FIBERS Method)', 'Adaptive with 0 evolving prob. (Best Score Thresholding)'], prop={'size': 10})
ax.set_ylim(-0.1, 1.1)
plt.xticks([1,2,3,4,5,6,7], [200,300,400,500,600,700,800])
plt.ylabel('True Risk Accuracy')
plt.xlabel('Number of Total Features')
# plt.title('Accuracy of top 10 FIBERS bins with varying total number of features')
plt.savefig('fig2_1.png', dpi=600)

# %%
root_folder = "run_history/"
summary_files = list()
score_files = list()
exp_files = os.listdir(root_folder)
for exp_file in exp_files:
    if exp_file.endswith(".csv"):
        if 'summary' in exp_file:
            summary_files.append(exp_file)
        if 'scores' in exp_file and 'old' not in exp_file:
            score_files.append(exp_file)
summary_files = sorted(summary_files)
score_files = sorted(score_files)
plot_df = pd.DataFrame()
metric = "Score"
top = 10

# %%
score_files
# Out:
# ['adaptive_Falseevolving_prob_0.0_thresh_0100bin_scores.csv',
#  'adaptive_Falseevolving_prob_0.0_thresh_1100bin_scores.csv',
#  'adaptive_Falseevolving_prob_0.0_thresh_2100bin_scores.csv',
#  'adaptive_Falseevolving_prob_0.0_thresh_3100bin_scores.csv',
#  'adaptive_Trueevolving_prob_0.0_thresh_0100bin_scores.csv',
#  'adaptive_Trueevolving_prob_0.0_thresh_1100bin_scores.csv',
#  'adaptive_Trueevolving_prob_0.0_thresh_2100bin_scores.csv',
#  'adaptive_Trueevolving_prob_0.0_thresh_3100bin_scores.csv',
#  'adaptive_Trueevolving_prob_0.5_thresh_0100bin_scores.csv',
#  'adaptive_Trueevolving_prob_0.5_thresh_1100bin_scores.csv',
#  'adaptive_Trueevolving_prob_0.5_thresh_2100bin_scores.csv',
#  'adaptive_Trueevolving_prob_0.5_thresh_3100bin_scores.csv',
#  'adaptive_Trueevolving_prob_1.0_thresh_0100bin_scores.csv',
#  'adaptive_Trueevolving_prob_1.0_thresh_1100bin_scores.csv',
#  'adaptive_Trueevolving_prob_1.0_thresh_2100bin_scores.csv',
# ...

# %%
tdf = pd.read_csv(root_folder + '/' + score_files[1])
tdf['P_Bins'] = tdf['Bins'].str.count('P')
tdf['R_Bins'] = tdf['Bins'].str.count('R')
tdf = tdf.head(10)
font_color = plt.cm.gray(0.0)
hfont = {'fontname':'Calibri'}
color_red = plt.cm.gray(0.5)
color_blue = plt.cm.gray(0.0)
index = tdf.index
column0 = tdf['R_Bins']
column1 = tdf['P_Bins']
title0 = "Random Bins"
title1 = 'Predictive Bins'

fig, axes = plt.subplots(figsize=(5,6), ncols=2,sharey=True)
# fig.tight_layout()

axes[0].barh(index, column0, align='center', color=color_red, zorder=10)
axes[0].set_title(title0, color=color_red)
axes[1].barh(index, column1, align='center', color=color_blue, zorder=10)
axes[1].set_title(title1, color=color_blue)
axes[0].set_xlim([0, 10])
axes[1].set_xlim([0, 10])


# If you have positive numbers and want to invert the x-axis of the left plot
axes[0].invert_xaxis() 


# To show data from highest to lowest
plt.gca().invert_yaxis()

axes[0].set(yticks=tdf.index, yticklabels=tdf.index)
axes[0].yaxis.tick_left()
axes[0].tick_params(axis='y', colors='white') # tick color

# axes[1].set_xticklabels(list(range(10)))


for label in (axes[0].get_xticklabels() + axes[0].get_yticklabels()):
    label.set(fontsize=13, color=font_color, **hfont)
for label in (axes[1].get_xticklabels() + axes[1].get_yticklabels()):
    label.set(fontsize=13, color=font_color, **hfont)
    
plt.subplots_adjust(wspace=0, top=0.85, bottom=0.1, left=0.18, right=0.95)
plt.show()
# Out:
# findfont: Font family ['Calibri'] not found. Falling back to DejaVu Sans.
